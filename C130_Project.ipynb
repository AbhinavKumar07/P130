# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavKumar07/P130/blob/main/C130_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

merged_df = pd.read_csv('https://drive.google.com/uc?id=1musMB4voEQGtIFlaHHIskY0OKLnIuJTn')

# %%
print(merged_df.shape)
# Out:
# (158, 6)

# %%
merged_df.dropna(axis=0, how="any", inplace=True) #Any = any of the values are N/A , axis = 0 --> rows , axis = 1 --> Columns
merged_df.head()
# Out:
#    Unnamed: 0  id                      Star_name  Distance      Mass    Radius
# 0           0   0  SDSS J000013.54+255418.6 [de]      46.1  0.045820  0.101735
# 1           1   1        2MASS J00040288-6410358     192.0  0.018137  0.167504
# 2           3   3        2MASS J00242463-0158201      37.7  0.075412  0.112012
# 3           5   5        2MASS J00274197+0503417     236.0  0.029592  0.147979
# 4           7   7         2MASSW J0030300-145033      87.2  0.051548  0.100708

# %%
print("Star info")
merged_df.info()
# Out:
# Star info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   id          158 non-null    int64
#  2   Star_name   158 non-null    object
#  3   Distance    158 non-null    float64
#  4   Mass        158 non-null    float64
#  5   Radius      158 non-null    float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 7.5+ KB

# %%
merged_df.describe()
# Out:
#        Unnamed: 0          id   Distance        Mass      Radius
# count  158.000000  158.000000  158.00000  158.000000  158.000000
# mean   100.575949  100.575949   67.69057    0.049542    0.229259
# std     59.018543   59.018543   53.37644    0.026897    0.816370
# min      0.000000    0.000000    6.51600    0.005728    0.088376
# 25%     49.500000   49.500000   35.02500    0.030785    0.099680
# 50%    101.500000  101.500000   51.00000    0.045820    0.104818
# 75%    148.500000  148.500000   80.00000    0.063957    0.136418
# max    284.000000  284.000000  380.00000    0.191872    7.398936

# %%
merged_df.dtypes
# Out:
# Unnamed: 0      int64
# id              int64
# Star_name      object
# Distance      float64
# Mass          float64
# Radius        float64
# dtype: object

# %%
from google.colab import files
merged_df.to_csv("cleaned.csv")
files.download('cleaned.csv')
